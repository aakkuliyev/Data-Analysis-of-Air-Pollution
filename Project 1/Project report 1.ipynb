# %%
import pandas as pd

air_pollution = pd.read_csv("Air_Quality.csv")
air_pollution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16122 entries, 0 to 16121
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       16122 non-null  int64
#  1   Indicator ID    16122 non-null  int64
#  2   Name            16122 non-null  object
#  3   Measure         16122 non-null  object
#  4   Measure Info    16122 non-null  object
#  5   Geo Type Name   16122 non-null  object
#  6   Geo Join ID     16122 non-null  int64
#  7   Geo Place Name  16122 non-null  object
#  8   Time Period     16122 non-null  object
#  9   Start_Date      16122 non-null  object
#  10  Data Value      16122 non-null  float64
#  11  Message         0 non-null      float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 1.5+ MB

# %%
air_pollution.columns
# Out:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Geo Place Name', 'Time Period',
#        'Start_Date', 'Data Value', 'Message'],
#       dtype='object')

# %%
air_pollution
# Out:
#        Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0         216498           386            Ozone (O3)    Mean          ppb
# 1         216499           386            Ozone (O3)    Mean          ppb
# 2         219969           386            Ozone (O3)    Mean          ppb
# 3         219970           386            Ozone (O3)    Mean          ppb
# 4         164876           383  Sulfur Dioxide (SO2)    Mean          ppb
# ...          ...           ...                   ...     ...          ...
# 16117     671118           386            Ozone (O3)    Mean          ppb
# 16118     671119           386            Ozone (O3)    Mean          ppb
# 16119     671120           386            Ozone (O3)    Mean          ppb
# 16120     671121           386            Ozone (O3)    Mean          ppb
# 16121     671122           386            Ozone (O3)    Mean          ppb
#
#       Geo Type Name  Geo Join ID                          Geo Place Name  \
# ...

# %% [markdown]
# We drop the Unique ID and Message columns.
# 1. We don't need the Unique Record Identifier.
# 2. We don't have any message in rows in dataset.

# %%
air_pollution = air_pollution.drop(columns = ["Unique ID","Message"])
air_pollution
# Out:
#        Indicator ID                  Name Measure Measure Info Geo Type Name  \
# 0               386            Ozone (O3)    Mean          ppb            CD
# 1               386            Ozone (O3)    Mean          ppb            CD
# 2               386            Ozone (O3)    Mean          ppb       Borough
# 3               386            Ozone (O3)    Mean          ppb       Borough
# 4               383  Sulfur Dioxide (SO2)    Mean          ppb            CD
# ...             ...                   ...     ...          ...           ...
# 16117           386            Ozone (O3)    Mean          ppb            CD
# 16118           386            Ozone (O3)    Mean          ppb            CD
# 16119           386            Ozone (O3)    Mean          ppb            CD
# 16120           386            Ozone (O3)    Mean          ppb            CD
# 16121           386            Ozone (O3)    Mean          ppb            CD
#
# ...

# %%
air_pollution[air_pollution.dtypes.index].isnull().any()
# Out:
# Indicator ID      False
# Name              False
# Measure           False
# Measure Info      False
# Geo Type Name     False
# Geo Join ID       False
# Geo Place Name    False
# Time Period       False
# Start_Date        False
# Data Value        False
# dtype: bool

# %%
air_pollution["Data Value"].mean()
# Out:
# 19.129162518473652

# %%
import matplotlib.pyplot as plt
import numpy as np
air_pollution.Measure.value_counts().plot(kind = 'bar')
plt.title("Measure Counts")
# Out:
# Text(0.5, 1.0, 'Measure Counts')

# %%
air_pollution.boxplot("Data Value")
# Out:
# <AxesSubplot:>

# %%
air_pollution.describe(include = 'float64')
# Out:
#          Data Value
# count  16122.000000
# mean      19.129163
# std       21.673789
# min        0.000000
# 25%        8.460000
# 50%       13.900000
# 75%       25.470000
# max      424.700000

# %%
air_pollution.Name.value_counts().plot(kind = 'bar')
plt.title("Name of Indicators")
# Out:
# Text(0.5, 1.0, 'Name of Indicators')

# %%
air_pollution=pd.DataFrame()

# %%
air_pollution.to_csv("Air_Pollution")
